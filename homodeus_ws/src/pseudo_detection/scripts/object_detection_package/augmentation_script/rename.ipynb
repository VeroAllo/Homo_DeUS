# %%
import os
folder = "./batch/v3/fruits-nobg"
for count, filename in enumerate(os.listdir(folder)):
    src =f"{folder}/{filename}"
    os.rename(src, folder+"/"+str(count+0)+ ".png")
    print(src+ " -> "+ folder+"/"+str(count+0)+ ".png")
# Out:
# ./batch/v3/fruits-nobg/20241127_132449.png -> ./batch/v3/fruits-nobg/0.png
# ./batch/v3/fruits-nobg/20241127_132452.png -> ./batch/v3/fruits-nobg/1.png
# ./batch/v3/fruits-nobg/20241127_132456.png -> ./batch/v3/fruits-nobg/2.png
# ./batch/v3/fruits-nobg/20241127_132458.png -> ./batch/v3/fruits-nobg/3.png
# ./batch/v3/fruits-nobg/20241127_132502.png -> ./batch/v3/fruits-nobg/4.png
# ./batch/v3/fruits-nobg/20241127_132505.png -> ./batch/v3/fruits-nobg/5.png
# ./batch/v3/fruits-nobg/20241127_132508.png -> ./batch/v3/fruits-nobg/6.png
# ./batch/v3/fruits-nobg/20241127_132510.png -> ./batch/v3/fruits-nobg/7.png
# ./batch/v3/fruits-nobg/20241127_132513.png -> ./batch/v3/fruits-nobg/8.png
# ./batch/v3/fruits-nobg/20241127_132516.png -> ./batch/v3/fruits-nobg/9.png
# ./batch/v3/fruits-nobg/20241127_132519.png -> ./batch/v3/fruits-nobg/10.png
# ./batch/v3/fruits-nobg/20241127_132521.png -> ./batch/v3/fruits-nobg/11.png
# ...
